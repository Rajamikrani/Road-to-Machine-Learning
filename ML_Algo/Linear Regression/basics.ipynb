# %% [markdown]
# ## Simple Linear regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("placement.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'] , df['package'])
plt.xlabel('cgpa')
plt.ylabel('package')
plt.show()

# %%
X = df.iloc[: , 0:1]
Y = df.iloc[: , -1]
X.head()
# Out:
#    cgpa
# 0  6.89
# 1  5.12
# 2  7.82
# 3  7.42
# 4  6.94

# %%
Y.head()
# Out:
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# Name: package, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain , Xtest , Ytrain , Ytest = train_test_split(X , Y , test_size=0.2 , random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(Xtrain , Ytrain)
# Out:
# LinearRegression()

# %%
Xtest.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
Ytest.head()
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# Name: package, dtype: float64

# %%
lr.predict(Xtest.iloc[0].values.reshape(1 ,1))
# Out:
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
m = lr.coef_
m
# Out:
# array([0.55795197])

# %%
c = lr.intercept_
c
# Out:
# np.float64(-0.8961119222429144)

# %%
# Y = mx + c
m*4.10 + c
# Out:
# array([1.39149117])

# %%
m*1 + c
# Out:
# array([-0.33815995])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(Xtrain,lr.predict(Xtrain),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# hours = np.array([1 ,2 ,1 , 4 ,3]).reshape([-1 , 1])
# score = np.array([3 , 4 , 2 ,7  , 6])
# model = LinearRegression().fit(hours , score)
# print("Intercept : " , model.intercept_)
# print("Slope : " , model.coef_)

# res = model.predict([[5]])
# # print(res)
# # It predict by using line equation where m = 1.55 and b = 0.97 then loop all x value 
# score_pred = model.predict(hours )
# print(score_pred)
# plt.scatter(hours , score)
# plt.plot(hours , score_pred)
# plt.show()
# Out:
# Intercept :  0.9705882352941173
# Slope :  [1.55882353]
# [2.52941176 4.08823529 2.52941176 7.20588235 5.64705882]
